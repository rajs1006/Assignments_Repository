# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
# Needed in Jupyter Notebook
# %matplotlib inline

def readdata():
    with open('expDat.txt','r') as f:
        df = pd.read_csv(f)
        print (df)
            
readdata()
# Out:
#     Unnamed: 0  V1  V2  V3  V4  V5  V6  V7  V8  V9 ...   V11  V12  V13  V14  \
# 0            1   1   0   0   2   2   0   2   3   2 ...     2    3    3    5
# 1            2   2   2   2   2   0   0   3   2   0 ...     0    1    3    0
# 2            3   3   2   3   2   3   2   2   2   2 ...     2    6    2    4
# 3            4   0   4   1   2   3   3   2   2   1 ...     0    2    4    2
# 4            5   6   2   1   2   0   5   1   2   4 ...     1    5    2    2
# 5            6   2   5   1   3   2   0   1   2   1 ...     2    0    4    3
# 6            7   4   2   2   2   4   1   1   1   2 ...     1    3    2    2
# 7            8   2   0   1   2   6   4   1   1   2 ...     0    2    3    2
# 8            9   0   2   1   1   1   2   2   2   2 ...     1    4    3    0
# 9           10   0   2   2   2   4   2   3   1   4 ...     1    2    4    2
# 10          11   2   3   3   4   4   4   2   2   2 ...     1    4    2    2
# ...
